# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import math
import operator
import matplotlib

# %%
main_link ="https://en.wikipedia.org/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction"

# %% [markdown]
# A very sad story is about to begin :(

# %%
class website:
    '''
    Class for the wiki website 
    '''
    def  __init__(self, link):
        '''
        Define e.g. where the module with links is 
        '''
        self.link = link
        r = requests.get(link)
        r.encoding='UTF-8'
        self.soup = BeautifulSoup(r.text,'lxml')
        self.books_module = self.findAll('li') # this is the module with links, welll... it should be. As a form of bs4

        
class book_page(website):
    '''
    Class for the particular book page = contains book author, name link to the book page etc. as an attribute
    '''
    def __init__(self, link):
        
        self.link = link
        r = requests.get(link)
        r.encoding='UTF-8'
        self.soup = BeautifulSoup(r.text,'lxml')
        self.name = ""
        self.author = ""
        self.country = ""
        
        
    def GetName(self):
        '''
         Scrape book name from book page method
         '''   
        self.name = self.soup.find('h1').text.strip()
        
        
    def GetAuthor (self):
        '''
         Scrape book author from book page method
        '''  
        self.author  = self.soup.find('table',{'class':'infobox vcard'}).text
 #no time for country

# %%
# Out:
# [<li class="toclevel-1 tocsection-1"><a href="#Common_titles"><span class="tocnumber">1</span> <span class="toctext">Common titles</span></a></li>,
#  <li class="toclevel-1 tocsection-2"><a href="#See_also"><span class="tocnumber">2</span> <span class="toctext">See also</span></a></li>,
#  <li class="toclevel-1 tocsection-3"><a href="#References"><span class="tocnumber">3</span> <span class="toctext">References</span></a></li>,
#  <li class="toclevel-1 tocsection-4"><a href="#External_links"><span class="tocnumber">4</span> <span class="toctext">External links</span></a></li>,
#  <li><a href="/wiki/Nineteen_Eighty-Four" title="Nineteen Eighty-Four">1984</a></li>,
#  <li><a href="/wiki/The_Ambassadors" title="The Ambassadors">The Ambassadors</a></li>,
#  <li><a href="/wiki/An_American_Tragedy" title="An American Tragedy">An American Tragedy</a></li>,
#  <li><a href="/wiki/Brave_New_World" title="Brave New World">Brave New World</a></li>,
#  <li><a href="/wiki/Catch-22" title="Catch-22">Catch-22</a></li>,
#  <li><a href="/wiki/The_Catcher_in_the_Rye" title="The Catcher in the Rye">The Catcher in the Rye</a></li>,
#  <li><a href="/wiki/A_Clockwork_Orange_(novel)" title="A Clockwork Orange (novel)">A Clockwork Orange</a></li>,
#  <li><a href="/wiki/The_Day_of_the_Locust" title="The Day of the Locust">The Day of the Locust</a></li>,
#  <li><a href="/wiki/Finnegans_Wake" title="Finnegans Wake">Finnegans Wake</a></li>,
#  <li><a href="/wiki/The_Grapes_of_Wrath" title="The Grapes of Wrath">The Grapes of Wrath</a></li>,
#  <li><a href="/wiki/The_Great_Gatsby" title="The Great Gatsby">The Great Gatsby</a></li>,
#  <li><a href="/wiki/Heart_of_Darkness" title="Heart of Darkness">Heart of Darkness</a></li>,
#  <li><a href="/wiki/The_House_of_Mirth" title="The House of Mirth">The House of Mirth</a></li>,
#  <li><a href="/wiki/Invisible_Man" title="Invisible Man">Invisible Man</a></li>,
#  <li><a href="/wiki/Ironweed_(novel)" title="Ironweed (novel)">Ironweed</a>*</li>,
#  <li><a href="/wiki/Lolita" title="Lolita">Lolita</a></li>,
#  <li><a href="/wiki/Midnight%27s_Children" title="Midnight's Children">Midnight's Children</a></li>,
#  <li><a href="/wiki/The_Naked_and_the_Dead" title="The Naked and the Dead">The Naked and the Dead</a></li>,
#  <li><a href="/wiki/Books_in_the_United_States" title="Books in the United States">US</a></li>,
#  <li>Formats
#  <ul><li><a href="/wiki/Audiobook" title="Audiobook">audiobooks</a></li>
#  <li><a href="/wiki/E-book" title="E-book">E-books</a></li></ul></li>,
#  <li><a href="/wiki/Audiobook" title="Audiobook">audiobooks</a></li>,
#  <li><a href="/wiki/E-book" title="E-book">E-books</a></li>,
#  <li>Genres
#  <ul><li><a href="/wiki/Fictional_book" title="Fictional book">fictional</a></li>
#  <li><a href="/wiki/Miniature_book" title="Miniature book">miniature</a></li>
#  <li><a href="/wiki/Pop-up_book" title="Pop-up book">pop-up</a></li></ul></li>,
#  <li><a href="/wiki/Fictional_book" title="Fictional book">fictional</a></li>,
#  <li><a href="/wiki/Miniature_book" title="Miniature book">miniature</a></li>,
#  <li><a href="/wiki/Pop-up_book" title="Pop-up book">pop-up</a></li>,
#  <li><a href="/wiki/History_of_books" title="History of books">History of books</a></li>,
#  <li><a href="/wiki/Intellectual_property" title="Intellectual property">Intellectual property</a></li>,
#  <li><a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN</a></li>,
#  <li><a href="/wiki/List_of_best-selling_books" title="List of best-selling books">List of best-selling books</a></li>,
#  <li><a href="/wiki/Outline_of_books" title="Outline of books">Outline</a></li>,
#  <li><a href="/wiki/Preservation_(library_and_archival_science)" title="Preservation (library and archival science)">Preservation</a></li>,
#  <li><img alt="Outline" data-file-height="200" data-file-width="130" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/10px-Global_thinking.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/15px-Global_thinking.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Global_thinking.svg/21px-Global_thinking.svg.png 2x" title="Outline" width="10"/> <a href="/wiki/Outline_of_books" title="Outline of books">Outline</a></li>,
#  <li><img alt="Category" data-file-height="31" data-file-width="36" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/4/48/Folder_Hexagonal_Icon.svg/16px-Folder_Hexagonal_Icon.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/48/Folder_Hexagonal_Icon.svg/24px-Folder_Hexagonal_Icon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/48/Folder_Hexagonal_Icon.svg/32px-Folder_Hexagonal_Icon.svg.png 2x" title="Category" width="16"/> <a href="/wiki/Category:Books" title="Category:Books">Category</a></li>,
#  <li><img alt="Portal" data-file-height="28" data-file-width="32" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/f/fd/Portal-puzzle.svg/16px-Portal-puzzle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/fd/Portal-puzzle.svg/24px-Portal-puzzle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/fd/Portal-puzzle.svg/32px-Portal-puzzle.svg.png 2x" title="Portal" width="16"/> <a href="/wiki/Portal:Books" title="Portal:Books">Portal</a></li>,
#  <li><a href="/wiki/Category:20th-century_novels" title="Category:20th-century novels">20th-century novels</a></li>,
#  <li><a href="/wiki/Category:Lists_of_novels" title="Category:Lists of novels">Lists of novels</a></li>,
#  <li><a href="/wiki/Category:Top_book_lists" title="Category:Top book lists">Top book lists</a></li>,
#  <li><a href="/wiki/Category:Articles_needing_additional_references_from_February_2011" title="Category:Articles needing additional references from February 2011">Articles needing additional references from February 2011</a></li>,
#  <li><a href="/wiki/Category:All_articles_needing_additional_references" title="Category:All articles needing additional references">All articles needing additional references</a></li>,
#  <li id="pt-anonuserpage">Not logged in</li>,
#  <li id="pt-anontalk"><a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]">Talk</a></li>,
#  <li id="pt-anoncontribs"><a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]">Contributions</a></li>,
#  <li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=20th+Century%27s+Greatest+Hits%3A+100+English-Language+Books+of+Fiction" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li>,
#  <li id="pt-login"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=20th+Century%27s+Greatest+Hits%3A+100+English-Language+Books+of+Fiction" title="You're encouraged to log in; however, it's not mandatory. [o]">Log in</a></li>,
#  <li class="selected" id="ca-nstab-main"><a accesskey="c" href="/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction" title="View the content page [c]">Article</a></li>,
#  <li id="ca-talk"><a accesskey="t" href="/wiki/Talk:20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction" rel="discussion" title="Discussion about the content page [t]">Talk</a></li>,
#  <li class="collapsible selected" id="ca-view"><a href="/wiki/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction">Read</a></li>,
#  <li class="collapsible" id="ca-edit"><a accesskey="e" href="/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;action=edit" title="Edit this page [e]">Edit</a></li>,
#  <li class="collapsible" id="ca-history"><a accesskey="h" href="/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;action=history" title="Past revisions of this page [h]">View history</a></li>,
#  <li id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">Main page</a></li>,
#  <li id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">Contents</a></li>,
#  <li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li>,
#  <li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li>,
#  <li id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Load a random article [x]">Random article</a></li>,
#  <li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li>,
#  <li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>,
#  <li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li>,
#  <li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li>,
#  <li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li>,
#  <li id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">Recent changes</a></li>,
#  <li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>,
#  <li id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction" title="List of all English Wikipedia pages containing links to this page [j]">What links here</a></li>,
#  <li id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction" rel="nofollow" title="Recent changes in pages linked from this page [k]">Related changes</a></li>,
#  <li id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">Upload file</a></li>,
#  <li id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">Special pages</a></li>,
#  <li id="t-permalink"><a href="/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;oldid=894055689" title="Permanent link to this revision of the page">Permanent link</a></li>,
#  <li id="t-info"><a href="/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;action=info" title="More information about this page">Page information</a></li>,
#  <li id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q4630676" title="Link to connected data repository item [g]">Wikidata item</a></li>,
#  <li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=20th_Century%27s_Greatest_Hits%3A_100_English-Language_Books_of_Fiction&amp;id=894055689" title="Information on how to cite this page">Cite this page</a></li>,
#  <li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=20th+Century%27s+Greatest+Hits%3A+100+English-Language+Books+of+Fiction">Create a book</a></li>,
#  <li id="coll-download-as-rl"><a href="/w/index.php?title=Special:ElectronPdf&amp;page=20th+Century%27s+Greatest+Hits%3A+100+English-Language+Books+of+Fiction&amp;action=show-download-screen">Download as PDF</a></li>,
#  <li id="t-print"><a accesskey="p" href="/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;printable=yes" title="Printable version of this page [p]">Printable version</a></li>,
#  <li id="footer-info-lastmod"> This page was last edited on 25 April 2019, at 10:09<span class="anonymous-show"> (UTC)</span>.</li>,
#  <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
#  additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>,
#  <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>,
#  <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>,
#  <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>,
#  <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>,
#  <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>,
#  <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/v2/#/en.wikipedia.org">Statistics</a></li>,
#  <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>,
#  <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=20th_Century%27s_Greatest_Hits:_100_English-Language_Books_of_Fiction&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>,
#  <li id="footer-copyrightico">
#  <a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/></a> </li>,
#  <li id="footer-poweredbyico">
#  <a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/></a> </li>]

# %%
class WIKI_downloader:

    def __init__(self, link):
        '''
        What are we about to extract?
        '''   
        self.main_link = link #link of the main  page
        self.main_website = website(link) #website object based on the lik
        self.main_soup = self.main_website.soup #it's soup
        self.book_hrefs = [] #list of url pieces scraped from the list of books on this main page 
        self.book_links = [] #actual URL links built on those href pieces
        self.count_links = 0 #their number
        self.book_pages = []#page objects on the book_liks
        self.output = pd.DataFrame(columns = ["Title", "Author","Country"]) #the pandastable
        
    def ListLinks(self):
        '''
        Extract the link endings for particular books
        Make them actual links
        '''
        self.book_hrefs = self.main_website.books_module.findAll('a',{'class':'external text'})
        self.count_links = len(book_hrefs)        
        self.book_links = [None]*range(self.count_links)
        for link in range(links):
            self.book_links[i] = 'https://en.wikipedia.org' + link['href']
 
    def getPages(self):
        '''
        turn the extracted links into bok page objects will all existing attributes and methods
        '''
        self.book_pages = [None]*range(l)
        for i in range(l):
              try self.book_pages[i]= book_page(self.book_links[i])
                except print("There is no book page for this link")
      
    
    def getBookTables(self):
        '''
        Fill the panda tables by using methods fo page objects and the book pages
        '''   
        for i in range(l):
            self.output.loc["Title",i]= self.book_pages[i].name
            self.output.loc["Author",i]= self.book_pages[i].author
            self.output.loc["Country",i]= self.book_pages[i].author

        self.output.MultiIndex(levels = ['Author','Country'])
        
    

#now run the methods one by one to reach the solution
T=WIKI_downloader(main_link)
T.ListLinks
T.getPages
T.


# and shall the code be working properly, i could play with the pandas right now. 
# but it's not working, so see you next week!

# %% [markdown]
# All the 34 books match with a page, the oldest one is from 1993 (the Ambassadors) and most the most frequent author is Joyce wiht two books.
